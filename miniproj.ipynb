# %% [markdown]
# Guess the number.

# %%
import random 
randNum = random.randint(1,5)
print(randNum)
# Out:
# 4

# %%
import random 
target = random.randint(1,100)

while True:
    userChoice = int(input("Guess the number: "))
    if(userChoice == target):
        print("sucess : Correct guess")
        break
    elif(userChoice < target):
        print("your number was too small. Take a bigger guess...")
    else:
        print("your number was too big. Take a smaller guess..")


print("----Game Over---")
# Out:
# your number was too big. Take a smaller guess..
# your number was too big. Take a smaller guess..
# your number was too big. Take a smaller guess..
# your number was too big. Take a smaller guess..
# your number was too big. Take a smaller guess..
# your number was too small. Take a bigger guess...
# your number was too big. Take a smaller guess..
# sucess : Correct guess
# ----Game Over---

# %%
import random 
target = random.randint(1,100)

while True:
    userChoice = int(input("Guess the number or Quit: "))
    if (userChoice == "Quit"):
        break
    userChoice = int(userChoice)
    if(userChoice == target):
        print("sucess : Correct guess")
        break
    elif(userChoice < target):
        print("your number was too small. Take a bigger guess...")
    else:
        print("your number was too big. Take a smaller guess..")


print("----Game Over---")
# Out:
# your number was too small. Take a bigger guess...

# %% [markdown]
# Random Password Generator

# %%
# example
import random
val = random.choice([1,2,3])
print(val)
# Out:
# 2

# %%
import string

pass_len=12
charValue = string.ascii_letters + string.digits + string.punctuation

password = " "
for i in range(pass_len):
    password += random.choice(charValue)

print("your random password is:",password)
# Out:
# your random password is:  $q]ui\xs4n46

# %%
# if we want to wrte our code in list compriantion
import string

pass_len=8
charValue = string.ascii_letters + string.digits + string.punctuation

# list comprehension [function for i in range(n)]

password = " ".join([random.choice(charValue) for i in range(pass_len)]) # .join() = the string whose method 
# is called is inserted in between each given string. The result is retured as a new string.
#print(res)

#password = " "
#for i in range(pass_len):
#    password += random.choice(charValue)

print("your random password is:",password)
# Out:
# your random password is: + D < j > h 4 7
